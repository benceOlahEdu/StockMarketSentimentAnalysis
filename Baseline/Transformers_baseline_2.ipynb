# %% [markdown]
# # **Stock market news feed semantic analysis** *(Baseline Transformers)*

# %% [markdown]
# * https://colab.research.google.com/github/bentrevett/pytorch-sentiment-analysis/blob/master/6%20-%20Transformers%20for%20Sentiment%20Analysis.ipynb#scrollTo=IUvWqEq1oV7k
# * https://arxiv.org/abs/1706.03762
# * https://arxiv.org/abs/1810.04805

# %% [markdown]
# ## **A projekt előkészítése**

# %%
# attach drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://www.kaggle.com/aaron7sun/stocknews

# %%
# Copy the dataset to the local environment
# !cp "/content/drive/MyDrive/Combined_News_DJIA.csv" "Combined_News_DJIA.csv"

# %%
# set imports
import random
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import torch

# %%
# Number of merged news into one string
ROWS = 1 # because of the max length for bert, if removing stop words and punctations will increase

# Shuffle cycle number for the dataframe
SHUFFLE_CYCLE = 500

# Numpy random seed
NP_SEED = 1234

# Torch seed
TORCH_SEED = 1234

# Train percentage (train + valid)
TRAIN_SPLIT = 0.75

# Only validation split
VALIDATION_SPLIT = 0.2

# %%
# set seeds for reproduce
random.seed(NP_SEED)
torch.manual_seed(TORCH_SEED)
np.random.seed(NP_SEED)
torch.backends.cudnn.deterministic = True

if torch.cuda.is_available():
  torch.cuda.manual_seed_all(TORCH_SEED)

# %% [markdown]
# A Transformers telepítése és importálása.

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/ed/d5/f4157a376b8a79489a76ce6cfe147f4f3be1e029b7144fa7b8432e8acb26/transformers-4.4.2-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 4.3MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 17.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 33.5MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=1df28ffd529e8028df32be7ba98074d50195334a7ebd7cd02f3dfa71d142442d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.4.2

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…

# %% [markdown]
# Torchtext frissítése és importálása.

# %%
pip install torchtext==0.4.0
# Out:
# Collecting torchtext==0.4.0
#   Downloading https://files.pythonhosted.org/packages/43/94/929d6bd236a4fb5c435982a7eb9730b78dcd8659acf328fd2ef9de85f483/torchtext-0.4.0-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 3.0MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0) (1.8.0+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4.0) (4.41.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.4.0) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4.0) (1.24.3)
# Installing collected packages: torchtext
#   Found existing installation: torchtext 0.9.0
#     Uninstalling torchtext-0.9.0:
#       Successfully uninstalled torchtext-0.9.0
# Successfully installed torchtext-0.4.0

# %%
from torchtext import data

# %% [markdown]
# ## **Az adathalmaz előkészítése**

# %%
# Load the dataset 
df_combined = pd.read_csv('Combined_News_DJIA.csv', index_col = "Date")

# Show the dataframe
df_combined.head()
# Out:
#             Label  ...                                              Top25
# Date               ...
# 2008-08-08      0  ...           b"No Help for Mexico's Kidnapping Surge"
# 2008-08-11      1  ...  b"So this is what it's come to: trading sex fo...
# 2008-08-12      0  ...  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 2008-08-13      0  ...  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 2008-08-14      1  ...  b'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 26 columns]

# %%
# Find the cells with NaN and after the rows for them
is_NaN = df_combined.isnull()
row_has_NaN = is_NaN.any(axis = 1)
rows_with_NaN = df_combined[row_has_NaN]

# Replace them
df_combined = df_combined.replace(np.nan, " ")

# Check the process
is_NaN = df_combined.isnull()
row_has_NaN = is_NaN.any(axis = 1)
rows_with_NaN = df_combined[row_has_NaN]

assert len(rows_with_NaN) is 0

# %%
# correct the wrong labels in the dataset

# Load the stock data
df_stock = web.DataReader("DJIA", data_source="yahoo", start="2008-08-08", 
                          end="2016-07-01")

temp_day = []

for day in range(len(df_stock)):
    temp_day.append(df_stock.index[day].date())

df_stock.index = temp_day

difference = []

if len(df_combined) == len(df_stock):
    print("The lengths are the same!")

for day in range(max(len(df_combined), len(df_stock))):
    if str(df_combined.index[day]) != str(df_stock.index[day]):
        print("There is difference at: " + str(day) + " index")
        print("News: " + str(df_combined.index[day]) + "\tStock: " + str(df_stock.index[day]))
        difference.append(day)

if len(difference) is 0:
    print("The dates matched!")

    difference = []

for day in range(len(df_stock)):
    # label should be 1 -> rise
    if int(df_stock["Adj Close"][day]) >= int(df_stock["Adj Close"][day - 1]):
        if df_combined["Label"][day] != 1:
            difference.append(str(df_stock.index[day]))
            print("Problem at day " + str(df_stock.index[day]))
            print("Today: " + str(df_stock["Adj Close"][day]) +"\t\tYesterday: " + str(df_stock["Adj Close"][day - 1]) + "\t\tLabel: " + str(df_combined["Label"][day]) + "\n")

    # label should be 0 -> fall
    if int(df_stock["Adj Close"][day]) < int(df_stock["Adj Close"][day - 1]):
        if df_combined["Label"][day] != 0:
            difference.append(str(df_stock.index[day]))
            print("Problem at day " + str(df_stock.index[day]))
            print("Today: " + str(df_stock["Adj Close"][day]) +"\t\tYesterday: " + str(df_stock["Adj Close"][day - 1]) + "\t\tLabel: " + str(df_combined["Label"][day]) + "\n")

print("All differences: " + str(len(difference))) 

# correct the wrong labels
for row in difference:
    if df_combined.loc[row, "Label"] == 0:
        df_combined.loc[row, "Label"] = 1
    else:
        df_combined.loc[row, "Label"] = 0

# check them
for row in difference:
    print(str(row) + "\t\t" + str(df_combined.loc[row, "Label"]))
# Out:
# The lengths are the same!
# The dates matched!
# Problem at day 2010-10-14
# Today: 11096.919921875		Yesterday: 11096.080078125		Label: 0
#
# Problem at day 2012-11-12
# Today: 12815.080078125		Yesterday: 12815.3896484375		Label: 0
#
# Problem at day 2012-11-15
# Today: 12570.9501953125		Yesterday: 12570.9501953125		Label: 0
#
# Problem at day 2013-04-12
# Today: 14865.0595703125		Yesterday: 14865.1396484375		Label: 0
#
# Problem at day 2014-04-24
# Today: 16501.650390625		Yesterday: 16501.650390625		Label: 0
#
# Problem at day 2015-08-12
# Today: 17402.509765625		Yesterday: 17402.83984375		Label: 0
#
# Problem at day 2015-11-27
# Today: 17813.390625		Yesterday: 17813.390625		Label: 0
#
# All differences: 7
# 2010-10-14		1
# 2012-11-12		1
# 2012-11-15		1
# 2013-04-12		1
# 2014-04-24		1
# 2015-08-12		1
# 2015-11-27		1

# %%
# combine the news and remove the 'b' char at the beginning
# no other preprocess, the tokenizer will take care of it

# Get column names
combined_column_names = []
for column in df_combined.columns:
  combined_column_names.append(column)

# 2D array creation for the news based on macros
COLUMNS = len(df_combined)
news_sum = [[0 for i in range(COLUMNS)] for j in range(int((len(combined_column_names) - 1) / ROWS))]  

# Merge the news
for row in range(len(df_combined)):
  for column in range(int((len(combined_column_names) - 1) / ROWS)):
    temp = ""
    news = ""
    for word in range(ROWS):
      news = df_combined[combined_column_names[(column * ROWS) + (word + 1)]][row]
      # Remove the b character at the begining of the string
      if news[0] is "b":
        news = " " + news[1:]
      temp = temp + news
    news_sum[column][row] = temp

# Drop the old columns
for column in range(len(combined_column_names) - 1):
  df_combined.drop(combined_column_names[column + 1], axis = 1, inplace = True)

# Create the new columns with the merged news
for column in range(int((len(combined_column_names) - 1) / ROWS)):
  colum_name = "News_" + str(column + 1)
  df_combined[colum_name] = news_sum[column]

# Show the DataFrame
df_combined.head()
# Out:
#             Label  ...                                            News_25
# Date               ...
# 2008-08-08      0  ...            "No Help for Mexico's Kidnapping Surge"
# 2008-08-11      1  ...   "So this is what it's come to: trading sex fo...
# 2008-08-12      0  ...   "BBC NEWS | Asia-Pacific | Extinction 'by man...
# 2008-08-13      0  ...   '2006: Nobel laureate Aleksander Solzhenitsyn...
# 2008-08-14      1  ...   'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 26 columns]

# %%
# create new dataset without the dates
news_sum = []
label_sum = []

# Get the column names
combined_column_names = []
for column in df_combined.columns:
  combined_column_names.append(column)

# Connect the merged news with the labels
for column in range(len(df_combined)):
  for row in range(len(combined_column_names) - 1):
    news_sum.append(df_combined[combined_column_names[row + 1]][column])
    label_sum.append(df_combined[combined_column_names[0]][column])

# Create the new DataFrame
df_sum_news_labels = pd.DataFrame(data = label_sum, index = None, columns = ["Label"])
df_sum_news_labels["News"] = news_sum

# Show it
df_sum_news_labels.head()
# Out:
#    Label                                               News
# 0      0   "Georgia 'downs two Russian warplanes' as cou...
# 1      0             'BREAKING: Musharraf to be impeached.'
# 2      0   'Russia Today: Columns of troops roll into So...
# 3      0   'Russian tanks are moving towards the capital...
# 4      0   "Afghan children raped with 'impunity,' U.N. ...

# %%
# check and delete the null length cells
news_sum = df_sum_news_labels["News"]
null_indexes = []
index = 0

for line in news_sum:
  if line is "":
    null_indexes.append(index)
  index = index + 1

print(null_indexes)

for row in null_indexes:
  df_sum_news_labels = df_sum_news_labels.drop(row)

news_sum = df_sum_news_labels["News"]
null_indexes = []
index = 0

for line in news_sum:
  if line is "":
    null_indexes.append(index)
  index = index + 1
  
assert len(null_indexes) is 0
# Out:
# []

# %%
# shuffle the dataset
# Do the shuffle
for i in range(SHUFFLE_CYCLE):
  df_sum_news_labels = shuffle(df_sum_news_labels, random_state = NP_SEED)

# Reset the index
df_sum_news_labels.reset_index(inplace=True, drop=True)

# %%
# check max length for bert tokenizer
# Get the column names
combined_column_names = []
for column in df_combined.columns:
  combined_column_names.append(column)

max_length = 0
# Connect the merged news with the labels
for column in range(len(df_combined)):
  for row in range(len(combined_column_names) - 1):
    if len(df_combined[combined_column_names[row + 1]][column]) > max_length:
        max_length = len(df_combined[combined_column_names[row + 1]][column])

max_length
# Out:
# 312

# %%
# split the dataset for train and validation and test 
INPUT_SIZE = len(df_sum_news_labels)
# 75% train -> 60% train, 15% valid, 25% test
TRAIN_SIZE = int(TRAIN_SPLIT * INPUT_SIZE) 
VALID_SIZE = int(VALIDATION_SPLIT * TRAIN_SIZE)

# Create the train data set
train_dataset = df_sum_news_labels[:TRAIN_SIZE - VALID_SIZE] 

# Create the validation data set
valid_dataset = df_sum_news_labels[TRAIN_SIZE - VALID_SIZE:TRAIN_SIZE] 

# Create the test data set
test_dataset = df_sum_news_labels[TRAIN_SIZE:]

# Save them without the indexes
train_dataset.to_csv('drive/MyDrive/train.tsv', sep = '\t', index=False)
valid_dataset.to_csv('drive/MyDrive/valid.tsv', sep = '\t', index=False)
test_dataset.to_csv('drive/MyDrive/test.tsv', sep = '\t', index=False)

# %%
# check label percentage
# TRAIN
# Groupby by label
labels = train_dataset.groupby("Label")

# Summary statistic of all countries
labels.describe().head()
# Get the counts for labels
label_0_count = len(labels.get_group(0))
label_1_count = len(labels.get_group(1))

# Get the summary
label_sum = label_0_count + label_1_count

# The percentages
percentage_0 = label_0_count / label_sum
percentage_1 = label_1_count / label_sum

# Show
print("TRAIN\n")
print(f"0 Labels percentage: {percentage_0*100:.2f}%\n")
print(f"1 Labels percentage: {percentage_1*100:.2f}%")

# VALID
# Groupby by label
labels = valid_dataset.groupby("Label")

# Summary statistic of all countries
labels.describe().head()
# Get the counts for labels
label_0_count = len(labels.get_group(0))
label_1_count = len(labels.get_group(1))

# Get the summary
label_sum = label_0_count + label_1_count

# The percentages
percentage_0 = label_0_count / label_sum
percentage_1 = label_1_count / label_sum

# Show
print("\n\nVALID\n")
print(f"0 Labels percentage: {percentage_0*100:.2f}%\n")
print(f"1 Labels percentage: {percentage_1*100:.2f}%")

# TEST
# Groupby by label
labels = test_dataset.groupby("Label")

# Summary statistic of all countries
labels.describe().head()
# Get the counts for labels
label_0_count = len(labels.get_group(0))
label_1_count = len(labels.get_group(1))

# Get the summary
label_sum = label_0_count + label_1_count

# The percentages
percentage_0 = label_0_count / label_sum
percentage_1 = label_1_count / label_sum

# Show
print("\n\nTEST\n")
print(f"0 Labels percentage: {percentage_0*100:.2f}%\n")
print(f"1 Labels percentage: {percentage_1*100:.2f}%")
# Out:
# TRAIN
#
# 0 Labels percentage: 46.45%
#
# 1 Labels percentage: 53.55%
#
#
# VALID
#
# 0 Labels percentage: 46.10%
#
# 1 Labels percentage: 53.90%
#
#
# TEST
#
# 0 Labels percentage: 45.28%
#
# 1 Labels percentage: 54.72%

# %%
train_dataset["News"][0]
# Out:
# " 'Report in US undercuts Georgian claim of how war started'"

# %% [markdown]
# ## **Szótárak létrehozása a szöveg kódolásához**

# %%
# define max input length for bert
max_input_length = tokenizer.max_model_input_sizes['bert-base-uncased']

# %%
# preprocess function with tokenizer
def tokenize_and_cut(sentence):
    tokens = tokenizer.tokenize(sentence) 
    tokens = tokens[:max_input_length-2]
    return tokens

# %%
# special tokens
init_token_idx = tokenizer.cls_token_id
eos_token_idx = tokenizer.sep_token_id
pad_token_idx = tokenizer.pad_token_id
unk_token_idx = tokenizer.unk_token_id

# %%
# fields define
TEXT = data.Field(batch_first = True,
                  use_vocab = False,
                  tokenize = tokenize_and_cut,
                  preprocessing = tokenizer.convert_tokens_to_ids,
                  init_token = init_token_idx,
                  eos_token = eos_token_idx,
                  pad_token = pad_token_idx,
                  unk_token = unk_token_idx)

LABEL = data.LabelField(dtype = torch.float)

# %%
fields = [('labels', LABEL), ('news', TEXT)]

# %%
# load datasets
train_data, valid_data, test_data = data.TabularDataset.splits(
                                        path = "drive/MyDrive",
                                        train = "train.tsv",
                                        validation = "valid.tsv",
                                        test = "test.tsv",
                                        format = "tsv",
                                        fields = fields,
                                        skip_header = True
)

# %%
print(f"Number of training examples: {len(train_data)}")
print(f"Number of validation examples: {len(valid_data)}")
print(f"Number of testing examples: {len(test_data)}")
# Out:
# Number of training examples: 29835
# Number of validation examples: 7458
# Number of testing examples: 12432

# %% [markdown]
# Az első elem ellenőrzése.

# %%
print(vars(train_data[0]))
# Out:
# {'labels': '1', 'news': [1005, 3189, 1999, 2149, 2104, 12690, 2015, 9166, 4366, 1997, 2129, 2162, 2318, 1005]}

# %%
tokens = tokenizer.convert_ids_to_tokens(vars(train_data[0])['news'])

print(tokens)
# Out:
# ["'", 'report', 'in', 'us', 'under', '##cut', '##s', 'georgian', 'claim', 'of', 'how', 'war', 'started', "'"]

# %%
# build vocab
LABEL.build_vocab(train_data)
print(LABEL.vocab.stoi)
# Out:
# defaultdict(None, {'1': 0, '0': 1})

# %%
# define batch and iterator
BATCH_SIZE = 128

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    sort_key = lambda x: x.news, #sort by n attribute (quote)
    batch_size = BATCH_SIZE, 
    sort_within_batch = True,
    device = device)

# %% [markdown]
# ## **Modell létrehozása**

# %%
# load pretrained bert
from transformers import BertTokenizer, BertModel

bert = BertModel.from_pretrained('bert-base-uncased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=440473133.0, style=ProgressStyle(descri…

# %%
# define model
import torch.nn as nn

class BERTGRUSentiment(nn.Module):
    def __init__(self,
                 bert,
                 hidden_dim,
                 output_dim,
                 n_layers,
                 bidirectional,
                 dropout):
        
        super().__init__()
        
        self.bert = bert # bert layer
        
        embedding_dim = bert.config.to_dict()['hidden_size']
        
        self.rnn = nn.GRU(embedding_dim,
                          hidden_dim,
                          num_layers = n_layers,
                          bidirectional = bidirectional,
                          batch_first = True,
                          dropout = 0 if n_layers < 2 else dropout) # gru layer
        
        self.out = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim) # linear out
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, text):
        
        #text = [batch size, sent len]
                
        with torch.no_grad():
            embedded = self.bert(text)[0] # do not teach the bert layer parameters
                
        #embedded = [batch size, sent len, emb dim]
        
        _, hidden = self.rnn(embedded)
        
        #hidden = [n layers * n directions, batch size, emb dim]
        
        if self.rnn.bidirectional:
            hidden = self.dropout(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1))
        else:
            hidden = self.dropout(hidden[-1,:,:])
                
        #hidden = [batch size, hid dim]
        
        output = self.out(hidden)
        
        #output = [batch size, out dim]
        
        return output

# %%
# create the model with parameters
HIDDEN_DIM = 128
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = False
DROPOUT = 0.25

model = BERTGRUSentiment(bert,
                         HIDDEN_DIM,
                         OUTPUT_DIM,
                         N_LAYERS,
                         BIDIRECTIONAL,
                         DROPOUT)

# %%
# check all and teachable parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} parameters')

for name, param in model.named_parameters():                
    if name.startswith('bert'):
        param.requires_grad = False

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 109,926,273 parameters
# The model has 444,033 trainable parameters

# %% [markdown]
# ## **A modell tanítása**

# %%
# optimizier and cost function
import torch.optim as optim
LR = 0.0001 # default for adam 0.001

criterion = nn.BCEWithLogitsLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=LR)

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', cooldown=6, 
#                                                       patience=4, verbose=True)

# place them to gpu
model = model.to(device)
criterion = criterion.to(device)

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    index = 0
    log_interval = 100
    
    model.train()
    
    for batch in iterator:
        if index == 0:
            all = str(len(iterator))
            print(f'Epoch: {epoch+1:02} started | {all} batches will be done')

        if index % log_interval == 0 and index > 0:
            all = str(len(iterator))
            temp_end_time = time.time()
            epoch_mins, epoch_secs = epoch_time(start_time, temp_end_time)
            print(f'Epoch: {epoch+1:02} | {index} / {all} batches done | Epoch Time: {epoch_mins}m {epoch_secs}s')
            
        optimizer.zero_grad()
        
        predictions = model(batch.news).squeeze(1)
        
        loss = criterion(predictions, batch.labels)
        
        acc = binary_accuracy(predictions, batch.labels)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()

        index += 1
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:

            predictions = model(batch.news).squeeze(1)
            
            loss = criterion(predictions, batch.labels)
            
            acc = binary_accuracy(predictions, batch.labels)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
import time

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
# train the model
# save the results for plotting
N_EPOCHS = 100

train_loss_array = []
train_acc_array = []
valid_loss_array = []
valid_acc_array = []

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    #scheduler.step(valid_loss)

    train_loss_array.append(train_loss)
    train_acc_array.append(train_acc)
    valid_loss_array.append(valid_loss)
    valid_acc_array.append(valid_acc)
        
    end_time = time.time()
        
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
        
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'drive/MyDrive/bert_best_model.pt')
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%\n')
# Out:
# Epoch: 01 started | 234 batches will be done
# Epoch: 01 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 01 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 01 | Epoch Time: 4m 41s
# 	Train Loss: 0.692 | Train Acc: 52.59%
# 	 Val. Loss: 0.690 |  Val. Acc: 53.68%
#
# Epoch: 02 started | 234 batches will be done
# Epoch: 02 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 02 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 02 | Epoch Time: 4m 42s
# 	Train Loss: 0.692 | Train Acc: 52.88%
# 	 Val. Loss: 0.693 |  Val. Acc: 53.83%
#
# Epoch: 03 started | 234 batches will be done
# Epoch: 03 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 03 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 03 | Epoch Time: 4m 42s
# 	Train Loss: 0.692 | Train Acc: 53.24%
# 	 Val. Loss: 0.690 |  Val. Acc: 53.86%
#
# Epoch: 04 started | 234 batches will be done
# Epoch: 04 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 04 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 04 | Epoch Time: 4m 42s
# 	Train Loss: 0.692 | Train Acc: 52.92%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.93%
#
# Epoch: 05 started | 234 batches will be done
# Epoch: 05 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 05 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 05 | Epoch Time: 4m 42s
# 	Train Loss: 0.692 | Train Acc: 53.03%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.81%
#
# Epoch: 06 started | 234 batches will be done
# Epoch: 06 | 100 / 234 batches done | Epoch Time: 1m 36s
# Epoch: 06 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 06 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 52.98%
# 	 Val. Loss: 0.692 |  Val. Acc: 53.54%
#
# Epoch: 07 started | 234 batches will be done
# Epoch: 07 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 07 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 07 | Epoch Time: 4m 43s
# 	Train Loss: 0.691 | Train Acc: 53.35%
# 	 Val. Loss: 0.690 |  Val. Acc: 53.59%
#
# Epoch: 08 started | 234 batches will be done
# Epoch: 08 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 08 | 200 / 234 batches done | Epoch Time: 3m 18s
# Epoch: 08 | Epoch Time: 4m 43s
# 	Train Loss: 0.691 | Train Acc: 53.51%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.79%
#
# Epoch: 09 started | 234 batches will be done
# Epoch: 09 | 100 / 234 batches done | Epoch Time: 1m 40s
# Epoch: 09 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 09 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 53.25%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.74%
#
# Epoch: 10 started | 234 batches will be done
# Epoch: 10 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 10 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 10 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 53.48%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.83%
#
# Epoch: 11 started | 234 batches will be done
# Epoch: 11 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 11 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 11 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.38%
# 	 Val. Loss: 0.690 |  Val. Acc: 53.81%
#
# Epoch: 12 started | 234 batches will be done
# Epoch: 12 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 12 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 12 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 53.40%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.64%
#
# Epoch: 13 started | 234 batches will be done
# Epoch: 13 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 13 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 13 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.49%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.82%
#
# Epoch: 14 started | 234 batches will be done
# Epoch: 14 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 14 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 14 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.55%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.85%
#
# Epoch: 15 started | 234 batches will be done
# Epoch: 15 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 15 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 15 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 53.35%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.74%
#
# Epoch: 16 started | 234 batches will be done
# Epoch: 16 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 16 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 16 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.45%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.83%
#
# Epoch: 17 started | 234 batches will be done
# Epoch: 17 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 17 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 17 | Epoch Time: 4m 43s
# 	Train Loss: 0.691 | Train Acc: 53.76%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.90%
#
# Epoch: 18 started | 234 batches will be done
# Epoch: 18 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 18 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 18 | Epoch Time: 4m 41s
# 	Train Loss: 0.690 | Train Acc: 53.52%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.91%
#
# Epoch: 19 started | 234 batches will be done
# Epoch: 19 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 19 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 19 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.64%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.94%
#
# Epoch: 20 started | 234 batches will be done
# Epoch: 20 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 20 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 20 | Epoch Time: 4m 41s
# 	Train Loss: 0.691 | Train Acc: 53.36%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.77%
#
# Epoch: 21 started | 234 batches will be done
# Epoch: 21 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 21 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 21 | Epoch Time: 4m 42s
# 	Train Loss: 0.691 | Train Acc: 53.43%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.93%
#
# Epoch: 22 started | 234 batches will be done
# Epoch: 22 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 22 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 22 | Epoch Time: 4m 43s
# 	Train Loss: 0.690 | Train Acc: 53.70%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.87%
#
# Epoch: 23 started | 234 batches will be done
# Epoch: 23 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 23 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 23 | Epoch Time: 4m 42s
# 	Train Loss: 0.690 | Train Acc: 53.63%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.66%
#
# Epoch: 24 started | 234 batches will be done
# Epoch: 24 | 100 / 234 batches done | Epoch Time: 1m 36s
# Epoch: 24 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 24 | Epoch Time: 4m 41s
# 	Train Loss: 0.690 | Train Acc: 53.71%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.78%
#
# Epoch: 25 started | 234 batches will be done
# Epoch: 25 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 25 | 200 / 234 batches done | Epoch Time: 3m 14s
# Epoch: 25 | Epoch Time: 4m 41s
# 	Train Loss: 0.690 | Train Acc: 53.56%
# 	 Val. Loss: 0.691 |  Val. Acc: 52.98%
#
# Epoch: 26 started | 234 batches will be done
# Epoch: 26 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 26 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 26 | Epoch Time: 4m 43s
# 	Train Loss: 0.690 | Train Acc: 53.72%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.17%
#
# Epoch: 27 started | 234 batches will be done
# Epoch: 27 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 27 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 27 | Epoch Time: 4m 42s
# 	Train Loss: 0.690 | Train Acc: 53.63%
# 	 Val. Loss: 0.691 |  Val. Acc: 53.26%
#
# Epoch: 28 started | 234 batches will be done
# Epoch: 28 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 28 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 28 | Epoch Time: 4m 43s
# 	Train Loss: 0.690 | Train Acc: 53.70%
# 	 Val. Loss: 0.692 |  Val. Acc: 53.30%
#
# Epoch: 29 started | 234 batches will be done
# Epoch: 29 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 29 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 29 | Epoch Time: 4m 42s
# 	Train Loss: 0.690 | Train Acc: 53.68%
# 	 Val. Loss: 0.692 |  Val. Acc: 52.18%
#
# Epoch: 30 started | 234 batches will be done
# Epoch: 30 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 30 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 30 | Epoch Time: 4m 43s
# 	Train Loss: 0.689 | Train Acc: 53.89%
# 	 Val. Loss: 0.694 |  Val. Acc: 51.21%
#
# Epoch: 31 started | 234 batches will be done
# Epoch: 31 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 31 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 31 | Epoch Time: 4m 42s
# 	Train Loss: 0.689 | Train Acc: 54.17%
# 	 Val. Loss: 0.692 |  Val. Acc: 52.79%
#
# Epoch: 32 started | 234 batches will be done
# Epoch: 32 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 32 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 32 | Epoch Time: 4m 44s
# 	Train Loss: 0.688 | Train Acc: 54.43%
# 	 Val. Loss: 0.694 |  Val. Acc: 52.10%
#
# Epoch: 33 started | 234 batches will be done
# Epoch: 33 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 33 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 33 | Epoch Time: 4m 42s
# 	Train Loss: 0.687 | Train Acc: 54.29%
# 	 Val. Loss: 0.694 |  Val. Acc: 51.67%
#
# Epoch: 34 started | 234 batches will be done
# Epoch: 34 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 34 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 34 | Epoch Time: 4m 43s
# 	Train Loss: 0.686 | Train Acc: 54.97%
# 	 Val. Loss: 0.697 |  Val. Acc: 51.43%
#
# Epoch: 35 started | 234 batches will be done
# Epoch: 35 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 35 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 35 | Epoch Time: 4m 42s
# 	Train Loss: 0.686 | Train Acc: 54.68%
# 	 Val. Loss: 0.700 |  Val. Acc: 48.70%
#
# Epoch: 36 started | 234 batches will be done
# Epoch: 36 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 36 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 36 | Epoch Time: 4m 42s
# 	Train Loss: 0.685 | Train Acc: 55.15%
# 	 Val. Loss: 0.697 |  Val. Acc: 51.39%
#
# Epoch: 37 started | 234 batches will be done
# Epoch: 37 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 37 | 200 / 234 batches done | Epoch Time: 3m 14s
# Epoch: 37 | Epoch Time: 4m 40s
# 	Train Loss: 0.685 | Train Acc: 55.29%
# 	 Val. Loss: 0.699 |  Val. Acc: 50.50%
#
# Epoch: 38 started | 234 batches will be done
# Epoch: 38 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 38 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 38 | Epoch Time: 4m 40s
# 	Train Loss: 0.684 | Train Acc: 55.74%
# 	 Val. Loss: 0.699 |  Val. Acc: 51.76%
#
# Epoch: 39 started | 234 batches will be done
# Epoch: 39 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 39 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 39 | Epoch Time: 4m 41s
# 	Train Loss: 0.681 | Train Acc: 56.31%
# 	 Val. Loss: 0.701 |  Val. Acc: 51.09%
#
# Epoch: 40 started | 234 batches will be done
# Epoch: 40 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 40 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 40 | Epoch Time: 4m 42s
# 	Train Loss: 0.680 | Train Acc: 56.30%
# 	 Val. Loss: 0.704 |  Val. Acc: 51.31%
#
# Epoch: 41 started | 234 batches will be done
# Epoch: 41 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 41 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 41 | Epoch Time: 4m 41s
# 	Train Loss: 0.678 | Train Acc: 57.10%
# 	 Val. Loss: 0.707 |  Val. Acc: 51.06%
#
# Epoch: 42 started | 234 batches will be done
# Epoch: 42 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 42 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 42 | Epoch Time: 4m 42s
# 	Train Loss: 0.676 | Train Acc: 57.11%
# 	 Val. Loss: 0.708 |  Val. Acc: 51.08%
#
# Epoch: 43 started | 234 batches will be done
# Epoch: 43 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 43 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 43 | Epoch Time: 4m 42s
# 	Train Loss: 0.673 | Train Acc: 57.84%
# 	 Val. Loss: 0.715 |  Val. Acc: 50.40%
#
# Epoch: 44 started | 234 batches will be done
# Epoch: 44 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 44 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 44 | Epoch Time: 4m 41s
# 	Train Loss: 0.670 | Train Acc: 58.35%
# 	 Val. Loss: 0.712 |  Val. Acc: 51.26%
#
# Epoch: 45 started | 234 batches will be done
# Epoch: 45 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 45 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 45 | Epoch Time: 4m 41s
# 	Train Loss: 0.667 | Train Acc: 58.95%
# 	 Val. Loss: 0.722 |  Val. Acc: 52.30%
#
# Epoch: 46 started | 234 batches will be done
# Epoch: 46 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 46 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 46 | Epoch Time: 4m 41s
# 	Train Loss: 0.660 | Train Acc: 59.77%
# 	 Val. Loss: 0.732 |  Val. Acc: 50.44%
#
# Epoch: 47 started | 234 batches will be done
# Epoch: 47 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 47 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 47 | Epoch Time: 4m 42s
# 	Train Loss: 0.653 | Train Acc: 60.99%
# 	 Val. Loss: 0.741 |  Val. Acc: 49.80%
#
# Epoch: 48 started | 234 batches will be done
# Epoch: 48 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 48 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 48 | Epoch Time: 4m 42s
# 	Train Loss: 0.649 | Train Acc: 61.63%
# 	 Val. Loss: 0.739 |  Val. Acc: 50.23%
#
# Epoch: 49 started | 234 batches will be done
# Epoch: 49 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 49 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 49 | Epoch Time: 4m 42s
# 	Train Loss: 0.642 | Train Acc: 62.41%
# 	 Val. Loss: 0.766 |  Val. Acc: 53.12%
#
# Epoch: 50 started | 234 batches will be done
# Epoch: 50 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 50 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 50 | Epoch Time: 4m 42s
# 	Train Loss: 0.635 | Train Acc: 63.23%
# 	 Val. Loss: 0.750 |  Val. Acc: 50.95%
#
# Epoch: 51 started | 234 batches will be done
# Epoch: 51 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 51 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 51 | Epoch Time: 4m 42s
# 	Train Loss: 0.628 | Train Acc: 63.58%
# 	 Val. Loss: 0.796 |  Val. Acc: 49.55%
#
# Epoch: 52 started | 234 batches will be done
# Epoch: 52 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 52 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 52 | Epoch Time: 4m 43s
# 	Train Loss: 0.621 | Train Acc: 64.57%
# 	 Val. Loss: 0.792 |  Val. Acc: 49.48%
#
# Epoch: 53 started | 234 batches will be done
# Epoch: 53 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 53 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 53 | Epoch Time: 4m 43s
# 	Train Loss: 0.612 | Train Acc: 65.24%
# 	 Val. Loss: 0.802 |  Val. Acc: 52.98%
#
# Epoch: 54 started | 234 batches will be done
# Epoch: 54 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 54 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 54 | Epoch Time: 4m 42s
# 	Train Loss: 0.601 | Train Acc: 66.18%
# 	 Val. Loss: 0.814 |  Val. Acc: 49.54%
#
# Epoch: 55 started | 234 batches will be done
# Epoch: 55 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 55 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 55 | Epoch Time: 4m 42s
# 	Train Loss: 0.594 | Train Acc: 66.99%
# 	 Val. Loss: 0.813 |  Val. Acc: 50.25%
#
# Epoch: 56 started | 234 batches will be done
# Epoch: 56 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 56 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 56 | Epoch Time: 4m 42s
# 	Train Loss: 0.581 | Train Acc: 68.00%
# 	 Val. Loss: 0.837 |  Val. Acc: 50.01%
#
# Epoch: 57 started | 234 batches will be done
# Epoch: 57 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 57 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 57 | Epoch Time: 4m 42s
# 	Train Loss: 0.579 | Train Acc: 68.21%
# 	 Val. Loss: 0.833 |  Val. Acc: 51.34%
#
# Epoch: 58 started | 234 batches will be done
# Epoch: 58 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 58 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 58 | Epoch Time: 4m 43s
# 	Train Loss: 0.569 | Train Acc: 68.86%
# 	 Val. Loss: 0.857 |  Val. Acc: 52.10%
#
# Epoch: 59 started | 234 batches will be done
# Epoch: 59 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 59 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 59 | Epoch Time: 4m 41s
# 	Train Loss: 0.556 | Train Acc: 70.03%
# 	 Val. Loss: 0.898 |  Val. Acc: 50.34%
#
# Epoch: 60 started | 234 batches will be done
# Epoch: 60 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 60 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 60 | Epoch Time: 4m 43s
# 	Train Loss: 0.550 | Train Acc: 70.36%
# 	 Val. Loss: 0.858 |  Val. Acc: 49.44%
#
# Epoch: 61 started | 234 batches will be done
# Epoch: 61 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 61 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 61 | Epoch Time: 4m 42s
# 	Train Loss: 0.546 | Train Acc: 70.64%
# 	 Val. Loss: 0.933 |  Val. Acc: 48.29%
#
# Epoch: 62 started | 234 batches will be done
# Epoch: 62 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 62 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 62 | Epoch Time: 4m 42s
# 	Train Loss: 0.535 | Train Acc: 71.29%
# 	 Val. Loss: 0.901 |  Val. Acc: 51.06%
#
# Epoch: 63 started | 234 batches will be done
# Epoch: 63 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 63 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 63 | Epoch Time: 4m 42s
# 	Train Loss: 0.524 | Train Acc: 72.29%
# 	 Val. Loss: 0.934 |  Val. Acc: 49.29%
#
# Epoch: 64 started | 234 batches will be done
# Epoch: 64 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 64 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 64 | Epoch Time: 4m 42s
# 	Train Loss: 0.517 | Train Acc: 72.33%
# 	 Val. Loss: 0.889 |  Val. Acc: 49.80%
#
# Epoch: 65 started | 234 batches will be done
# Epoch: 65 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 65 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 65 | Epoch Time: 4m 42s
# 	Train Loss: 0.509 | Train Acc: 73.17%
# 	 Val. Loss: 0.915 |  Val. Acc: 50.38%
#
# Epoch: 66 started | 234 batches will be done
# Epoch: 66 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 66 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 66 | Epoch Time: 4m 42s
# 	Train Loss: 0.501 | Train Acc: 73.52%
# 	 Val. Loss: 0.930 |  Val. Acc: 50.84%
#
# Epoch: 67 started | 234 batches will be done
# Epoch: 67 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 67 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 67 | Epoch Time: 4m 41s
# 	Train Loss: 0.500 | Train Acc: 73.71%
# 	 Val. Loss: 0.950 |  Val. Acc: 49.31%
#
# Epoch: 68 started | 234 batches will be done
# Epoch: 68 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 68 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 68 | Epoch Time: 4m 42s
# 	Train Loss: 0.492 | Train Acc: 73.98%
# 	 Val. Loss: 1.000 |  Val. Acc: 49.51%
#
# Epoch: 69 started | 234 batches will be done
# Epoch: 69 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 69 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 69 | Epoch Time: 4m 42s
# 	Train Loss: 0.483 | Train Acc: 74.47%
# 	 Val. Loss: 0.958 |  Val. Acc: 50.90%
#
# Epoch: 70 started | 234 batches will be done
# Epoch: 70 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 70 | 200 / 234 batches done | Epoch Time: 3m 17s
# Epoch: 70 | Epoch Time: 4m 42s
# 	Train Loss: 0.478 | Train Acc: 75.33%
# 	 Val. Loss: 1.026 |  Val. Acc: 51.33%
#
# Epoch: 71 started | 234 batches will be done
# Epoch: 71 | 100 / 234 batches done | Epoch Time: 1m 39s
# Epoch: 71 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 71 | Epoch Time: 4m 42s
# 	Train Loss: 0.480 | Train Acc: 75.03%
# 	 Val. Loss: 1.001 |  Val. Acc: 51.35%
#
# Epoch: 72 started | 234 batches will be done
# Epoch: 72 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 72 | 200 / 234 batches done | Epoch Time: 3m 14s
# Epoch: 72 | Epoch Time: 4m 41s
# 	Train Loss: 0.469 | Train Acc: 75.74%
# 	 Val. Loss: 1.006 |  Val. Acc: 50.06%
#
# Epoch: 73 started | 234 batches will be done
# Epoch: 73 | 100 / 234 batches done | Epoch Time: 1m 37s
# Epoch: 73 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 73 | Epoch Time: 4m 42s
# 	Train Loss: 0.465 | Train Acc: 75.73%
# 	 Val. Loss: 1.073 |  Val. Acc: 49.02%
#
# Epoch: 74 started | 234 batches will be done
# Epoch: 74 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 74 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 74 | Epoch Time: 4m 42s
# 	Train Loss: 0.452 | Train Acc: 76.87%
# 	 Val. Loss: 1.064 |  Val. Acc: 50.87%
#
# Epoch: 75 started | 234 batches will be done
# Epoch: 75 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 75 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 75 | Epoch Time: 4m 41s
# 	Train Loss: 0.446 | Train Acc: 76.77%
# 	 Val. Loss: 1.095 |  Val. Acc: 50.58%
#
# Epoch: 76 started | 234 batches will be done
# Epoch: 76 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 76 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 76 | Epoch Time: 4m 42s
# 	Train Loss: 0.443 | Train Acc: 77.20%
# 	 Val. Loss: 1.127 |  Val. Acc: 49.19%
#
# Epoch: 77 started | 234 batches will be done
# Epoch: 77 | 100 / 234 batches done | Epoch Time: 1m 36s
# Epoch: 77 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 77 | Epoch Time: 4m 42s
# 	Train Loss: 0.440 | Train Acc: 77.32%
# 	 Val. Loss: 1.092 |  Val. Acc: 50.55%
#
# Epoch: 78 started | 234 batches will be done
# Epoch: 78 | 100 / 234 batches done | Epoch Time: 1m 38s
# Epoch: 78 | 200 / 234 batches done | Epoch Time: 3m 16s
# Epoch: 78 | Epoch Time: 4m 42s
# 	Train Loss: 0.435 | Train Acc: 77.58%
# 	 Val. Loss: 1.119 |  Val. Acc: 50.61%
#
# Epoch: 79 started | 234 batches will be done
# Epoch: 79 | 100 / 234 batches done | Epoch Time: 1m 36s
# Epoch: 79 | 200 / 234 batches done | Epoch Time: 3m 15s
# Epoch: 79 | Epoch Time: 4m 41s
# 	Train Loss: 0.434 | Train Acc: 77.59%
# 	 Val. Loss: 1.134 |  Val. Acc: 49.71%
#
# Epoch: 80 started | 234 batches will be done

# %%
# Visualize the training
plt.figure(figsize=(16,8))
plt.title('Train and validation loss')
plt.plot(train_loss_array, color = "green", label = "Train loss")
plt.plot(valid_loss_array, color = "blue", label = "Valid loss")
plt.xlabel('Epoch',fontsize=18)
plt.ylabel('Loss',fontsize=18)
plt.legend(fontsize=18)
plt.show()

# %%
# Visualize the training
plt.figure(figsize=(16,8))
plt.title('Train and validation accuraccy')
plt.plot(train_acc_array, color = "green", label = "Train accuracy")
plt.plot(valid_acc_array, color = "blue", label = "Valid accuracy")
plt.xlabel('Epoch',fontsize=18)
plt.ylabel('Accuracy (%)',fontsize=18)
plt.legend(fontsize=18)
plt.show()

# %% [markdown]
# ## **A modell tesztelése**

# %%
model.load_state_dict(torch.load('drive/MyDrive/bert_best_model.pt'))

test_loss, test_acc = evaluate(model, test_iterator, criterion)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
