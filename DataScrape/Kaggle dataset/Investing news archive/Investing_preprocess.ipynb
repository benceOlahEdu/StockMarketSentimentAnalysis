# %%
import pandas as pd

# %%
# Load the dataset 
df = pd.read_csv('KAG_INVESTING_DF.csv')

df
# Out:
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        category                                            content  \
# ...

# %%
df.drop(['id', 'content', 'provider', 'url', 'article_id'], axis = 1, inplace = True)
df
# Out:
#        ticker                                              title category  \
# 0         NIO  Why Shares of Chinese Electric Car Maker NIO A...     news
# 1         NIO  NIO only consumer gainer  Workhorse Group amon...     news
# 2         NIO  NIO leads consumer gainers  Beyond Meat and Ma...     news
# 3         NIO                  NIO  NVAX among premarket gainers     news
# 4         NIO                  PLUG  NIO among premarket gainers     news
# ...       ...                                                ...      ...
# 221508      T                     Crude And Steel Still In Sync   opinion
# 221509      T  Forget AT T  This Is The Telecom Stock You Sho...  opinion
# 221510      T  Wall Street Exposed   Part 3   How Dividends C...  opinion
# 221511      T       Weighing The Week Ahead  It s All About Jobs  opinion
# 221512      T  Leap Wireless  LEAP    JPM Note and AT T   T M...  opinion
#
#        release_date
# 0        2020-01-15
# 1        2020-01-18
# ...

# %%
df_1 = df.iloc[:int((len(df) / 2)),:]
df_1
# Out:
#        ticker                                              title category  \
# 0         NIO  Why Shares of Chinese Electric Car Maker NIO A...     news
# 1         NIO  NIO only consumer gainer  Workhorse Group amon...     news
# 2         NIO  NIO leads consumer gainers  Beyond Meat and Ma...     news
# 3         NIO                  NIO  NVAX among premarket gainers     news
# 4         NIO                  PLUG  NIO among premarket gainers     news
# ...       ...                                                ...      ...
# 110751      R  J B  Hunt To Buy Cory 1st Choice Home Delivery...  opinion
# 110752      R  Ryder  R  Earnings Expected To Grow  What To K...  opinion
# 110753    BLK  Wal Mart resists investor pressure on independ...     news
# 110754      R  What s In The Cards For Ryder  R  This Earning...  opinion
# 110755      R  Ryder  R  Beats Q4 Earnings And Revenue Estimates  opinion
#
#        release_date
# 0        2020-01-15
# 1        2020-01-18
# ...

# %%
df_2 = df.iloc[int((len(df) / 2)):,:]
df_2
# Out:
#        ticker                                              title category  \
# 110756      R  Ryder  R  Q4 Earnings   Revenues Beat  2019 EP...  opinion
# 110757    MSI  Here s Why Motorola  MSI  Is A Great Momentum ...  opinion
# 110758    MSI  The Zacks Analyst Blog Highlights  Motorola So...  opinion
# 110759    MSI  Top Ranked Momentum Stocks To Buy For February...  opinion
# 110760    MSI  Moving Average Crossover Alert  Motorola Solut...  opinion
# ...       ...                                                ...      ...
# 221508      T                     Crude And Steel Still In Sync   opinion
# 221509      T  Forget AT T  This Is The Telecom Stock You Sho...  opinion
# 221510      T  Wall Street Exposed   Part 3   How Dividends C...  opinion
# 221511      T       Weighing The Week Ahead  It s All About Jobs  opinion
# 221512      T  Leap Wireless  LEAP    JPM Note and AT T   T M...  opinion
#
#        release_date
# 110756   2019-02-17
# 110757   2019-02-13
# ...

# %%
df_1.to_csv('KAG_INVESTING_DF_1.csv', index=False)
df_2.to_csv('KAG_INVESTING_DF_2.csv', index=False)
